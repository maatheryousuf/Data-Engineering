# %% [markdown]
# ### TravelInsurancePrediction dataset Visualization

# %% [markdown]
# ##### by: Maathar Al-saidi, Maather Al-Maamari

# %% [markdown]
# #### Exploratory research question: Which customer will be interested to buy the travel insurance package?

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
frame=pd.read_csv("TravelInsurancePrediction.csv")
frame
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 0              0   31             Government Sector           Yes
# 1              1   31  Private Sector/Self Employed           Yes
# 2              2   34  Private Sector/Self Employed           Yes
# 3              3   28  Private Sector/Self Employed           Yes
# 4              4   28  Private Sector/Self Employed           Yes
# ...          ...  ...                           ...           ...
# 1982        1982   33  Private Sector/Self Employed           Yes
# 1983        1983   28  Private Sector/Self Employed           Yes
# 1984        1984   28  Private Sector/Self Employed           Yes
# 1985        1985   34  Private Sector/Self Employed           Yes
# 1986        1986   34  Private Sector/Self Employed           Yes
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0           400000              6                1            No
# ...

# %%
unnamed_cols = frame.columns.str.contains('Unnamed')

frame_new = frame.drop(frame[frame.columns[unnamed_cols]], axis=1)

frame_new
# Out:
#       Age               Employment Type GraduateOrNot  AnnualIncome  \
# 0      31             Government Sector           Yes        400000
# 1      31  Private Sector/Self Employed           Yes       1250000
# 2      34  Private Sector/Self Employed           Yes        500000
# 3      28  Private Sector/Self Employed           Yes        700000
# 4      28  Private Sector/Self Employed           Yes        700000
# ...   ...                           ...           ...           ...
# 1982   33  Private Sector/Self Employed           Yes       1500000
# 1983   28  Private Sector/Self Employed           Yes       1750000
# 1984   28  Private Sector/Self Employed           Yes       1150000
# 1985   34  Private Sector/Self Employed           Yes       1000000
# 1986   34  Private Sector/Self Employed           Yes        500000
#
#       FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# 0                 6                1            No                  No
# ...

# %%
plt.pie(frame_new ["TravelInsurance"].value_counts(), labels=["0", "1"], autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1795a203100>,
# ...
#  [Text(-0.4767124851336916, 0.9913350626895329, '0'),
#   Text(0.47671257794917643, -0.9913350180564845, '1')],
#  [Text(-0.26002499189110445, 0.5407282160124725, '64.27%'),
#   Text(0.26002504251773256, -0.5407281916671733, '35.73%')])

# %% [markdown]
# #### From the above pie chart we can notice  that about 64.27% of the people in the dataset do not have travel insurance, while about 35.73% do.

# %%
frame_new[frame_new['TravelInsurance']==1]
# Out:
#       Age               Employment Type GraduateOrNot  AnnualIncome  \
# 2      34  Private Sector/Self Employed           Yes        500000
# 7      31  Private Sector/Self Employed           Yes       1350000
# 8      28  Private Sector/Self Employed           Yes       1450000
# 11     26  Private Sector/Self Employed           Yes       1400000
# 12     32             Government Sector           Yes        850000
# ...   ...                           ...           ...           ...
# 1977   25  Private Sector/Self Employed            No       1350000
# 1978   34  Private Sector/Self Employed           Yes        700000
# 1981   27             Government Sector           Yes        850000
# 1982   33  Private Sector/Self Employed           Yes       1500000
# 1985   34  Private Sector/Self Employed           Yes       1000000
#
#       FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# 2                 4                1            No                  No
# ...

# %% [markdown]
# #### We filtered the above dataset based on who buy the Travel Insurance, which means that Travel Insurance = 1. This will help us to determine which factor affect on buying Travel Insurance.

# %%
plt.hist(frame['ChronicDiseases'],color= 'blue')
plt.show()

# %% [markdown]
# #### From the above histogram we can notice that the numbers of people who don't  have ChronicDiseases is above 1400 person. On the other hand the numbers of peole who have ChronicDiseases is less than 600 person.

# %%
plt.hist(frame['Age'],color= 'red')
plt.show()

# %% [markdown]
#  #### From the above histogram we can notice that the largest numbers of people in this dataset their age between 28 and 29 and there are approximately 500 person. Also,  there a large number of people whose age above 34 years old.

# %%
plt.hist(frame['FrequentFlyer'],color= 'pink')
plt.show()

# %% [markdown]
# #### From the above histogram we can notice that the numbers of people who never have a FrequentFlyer  are more than 1400 person. On the other hand the numbers of peole who have FrequentFlyer are  neraly 400 person.

# %%
sns.catplot(x='ChronicDiseases' , y='Age',hue='FrequentFlyer',kind='box', data=frame)

# %% [markdown]
# ###### We noticed from the above chart that the group age that didn't travel much, and without chronic diseases is the same group age that didn't travel much, and had chronic diseases ranging between 28 and 32 years, while we noticed a difference in the age group that travels frequently, where the group age that travels frequently, and without chronic diseases is between 27 and 33 years old, and the group age that travels a lot and had chronic diseases is between 26 and 33 years.
#
# ###### We concluded that the number of people who travel frequently and had chronic diseases is greater than those without chronic diseases.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=frame, x='Age', hue='EverTravelledAbroad', multiple='stack', kde=True, palette='Reds')
plt.xlabel('Age')
plt.title('Distribution of Age by Travel History')

plt.show()

# %% [markdown]
# #### The majority of people in the dataset are between the ages of 20 and 40. There are more people who have not traveled abroad than people who have traveled abroad. The number of people who have traveled abroad increases as age decreases.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=frame, x= 'ChronicDiseases', hue='EverTravelledAbroad', multiple='stack', kde=True, palette='Reds')
plt.xlabel('ChronicDiseases')
plt.title('EverTravelledAbroad vs ChronicDiseases')

plt.show()

# %% [markdown]
# ###### We noticed from the above chart that there are more people without chronic diseases than those with chronic diseases. Moreover, the number of people without chronic diseases who have travelled abroad or haven't travelled is more than the other category.
